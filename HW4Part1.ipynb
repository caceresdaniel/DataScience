# %% [markdown]
# ## Importing all necessary sklearn methods

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.utils import resample
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ## Read the data set and placed it into a pandas dataframe

# %%
df = pd.read_csv('https://raw.githubusercontent.com/caceresdaniel/DataScience/master/Cancer.csv')
df
# Out:
#      Clump_Thickness  Uniformity_of_Cell_Size  Uniformity_of_Cell_Shape  \
# 0                  5                        1                         1
# 1                  5                        4                         4
# 2                  3                        1                         1
# 3                  6                        8                         8
# 4                  4                        1                         1
# 5                  8                       10                        10
# 6                  1                        1                         1
# 7                  2                        1                         2
# 8                  2                        1                         1
# 9                  4                        2                         1
# 10                 5                        3                         3
# 11                 8                        7                         5
# ...

# %% [markdown]
# ## Fitting the data into training and testing then making a prediction using decision tree classifier on the data, and finally calculating the accuracy of the prediction

# %%
feats = ['Clump_Thickness','Uniformity_of_Cell_Size','Uniformity_of_Cell_Shape','Marginal_Adhesion','Single_Epithelial_Cell_Size','Bare_Nuclei','Bland_Chromatin','Normal_Nucleoli','Mitoses']

x = df[feats]

y = df['Malignant_Cancer']


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.35,random_state=3)

dt = DecisionTreeClassifier(random_state=3)

dt.fit(x_train, y_train)

dtPredict = dt.predict(x_test)

dtacc = accuracy_score(y_test, dtPredict)

print(dtacc)
# Out:
# 0.8301886792452831

# %% [markdown]
# ## Doing Bagging on the dataset, by creating a for loop that resamples the data 19 times and then doing predictions on the resampled data using deccision tree classifier, after creating 19 predictions I do voting by finding the common element in each row after combining all predictions and finally getting the accuracy after doing the voting

# %%
# 1. make a bootstarp sample of the original “Training” Dataset (build in part(b)) with the
# size of bootstarp_size = 0.8*(Size of the original dataset). You can use the following
# command to generate a random bootstrap dataset (“i" is the variable of the loop, so
# the random_state changes in each iteration):
# resample(X_train, n_samples = bootstarp_size , random_state=i , replace = True)
# 2. Define and train a new base decision tree classifier on this dataset in each iteration:
# Base_DecisionTree = DecisionTreeClassifier(random_state=3).
# 3. Perform prediction using “this base classifier” on the original “Testing” Dataset X_test
# (build in part(b)), and save the prediction results for all testing samples.
preds = []

for i in range(0, 19):
    bootstarp_size = int(0.8*(df.size))
    x_samp, y_samp = resample(x_train,y_train, n_samples=bootstarp_size, random_state=i, replace=True)
    Base_DecisionTree = DecisionTreeClassifier(random_state=3)
    Base_DecisionTree.fit(x_samp,y_samp)
    pred = Base_DecisionTree.predict(x_test)
    preds.append(pred)

#Function that finds the most common element in the list
def most_common(lst):
    return max(set(lst), key=lst.count)    

vote = []
for i in range (0,53):
    temp = []
    for pred in preds:
        temp.append(pred[i])
    vote.append(most_common(temp))

acc = accuracy_score(y_test,vote)

print(acc)
# Out:
# 0.8679245283018868

# %% [markdown]
# ## Using Random Forest to get a prediction on the data set and then calculating the accuracy of that prediction

# %%
my_RandomForest =  RandomForestClassifier(n_estimators = 19, bootstrap = True, random_state=3)
my_RandomForest.fit(x_train,y_train)
rfpred = my_RandomForest.predict(x_test)
rfacc = accuracy_score(y_test,rfpred)
print(rfacc)
# Out:
# 0.9245283018867925
